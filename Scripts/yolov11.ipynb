# %%
from ultralytics import YOLO

model = YOLO("../models/yolo26x-pose.pt", task="pose")

results = model.track(source='../Data/flipturnHQ-cc.mp4', show=True, save=False)
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/307) c:\Users\reziv\OneDrive\Documents\GitHub\SwimVisionProject\Scripts\..\Data\flipturnHQ-cc.mp4: 384x640 2 persons, 567.0ms
# video 1/1 (frame 2/307) c:\Users\reziv\OneDrive\Documents\GitHub\SwimVisionProject\Scripts\..\Data\flipturnHQ-cc.mp4: 384x640 1 person, 470.7ms
# video 1/1 (frame 3/307) c:\Users\reziv\OneDrive\Documents\GitHub\SwimVisionProject\Scripts\..\Data\flipturnHQ-cc.mp4: 384x640 2 persons, 450.7ms
# ...
